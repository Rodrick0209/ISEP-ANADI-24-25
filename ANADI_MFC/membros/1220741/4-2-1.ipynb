# %% [markdown]
# # Imports Necessários

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Leitura de Dados e filtração de Dados

# %%
# comando read_csv para tal.
dados = pd.read_csv('../../dados/AIRPOL_data.csv', delimiter=";", header=0, decimal=',')
dados = dados.drop(columns=['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'])


soutEuDados = dados[dados['Country'].isin(['Greece', 'Spain', 'Italy', 'Portugal'])]
soutEuDadosNumericos = soutEuDados.select_dtypes(include=[np.number])

# %% [markdown]
# # Escolha de Representação de Correlação dos Dados: Heatmap a representar a matriz de confusão

# %%
corr = soutEuDadosNumericos.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlação entre Value (Ppremature Deaths) e os restantes atributos')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pequena Interpretação dos Dados
#
# - As variáveis **Affected_Population** e **Populated_Area[km2]** apresentam uma correlação **moderadamente positiva** com a variável o número de mortes prematuras (Value) , apresentando os seguintes graus de correlação: (graus de correlação r1=0.56 e r2=0.53).
#
#  - Desta forma podemos concluir que a maior parte das mortes foi causda por doenças que afetam a população em áreas mais populosas e com maior densidade populacional, aciciomente confirmamos que a media de poluição atmosférica é uma variável calculada que não tem qualquer influencia no numero de
#  mortes , dado que o seu grau de correlção ser praticamente nulo. ( r=-0.014951)
#
# - Enquanto que *Air_Pollution_Average[ug/m3]* apresenta uma correlação praticamente nula com "Value":
#   **Correlação = -0.014951**
#
# Isto indica que *a poluição atmosférica média não tem correlação significativa com a variável alvo* neste conjunto de dados.
